# %%
# !pip install -q transformers torch accelerate sentencepiece

# %%
# Import Library
# ==========================================================
import pandas as pd
import torch
import matplotlib.pyplot as plt

from transformers import (
    AutoTokenizer,
    AutoModelForSequenceClassification,
    pipeline
)

# %%
# ==========================================================
# Cek GPU
# ==========================================================
device = 0 if torch.cuda.is_available() else -1

if device == 0:
    print("Menggunakan GPU")
else:
    print("Menggunakan CPU")
# Out:
# Menggunakan GPU

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# ==========================================================
# Load Dataset
# ==========================================================
df = pd.read_csv("/content/drive/MyDrive/SKRIPSI MANTAP/data sosmed/.Process/Clean data/tt_clean.csv")   # ganti sesuai nama file

print(df.head())
print(f"\nJumlah data : {len(df)}")
# Out:
#                                         tt_clean
# 0              woilah temen gw berenang disitu😹😹
# 1                                uya kuya kapan🗿
# 2                         "woy ini mahal anj" 😭😭
# 3  jangan lupa eko patrio, uya kuya, nafa ubach,
# 4    reaksi syahroni pulang kaget jadi gelandang
#
# Jumlah data : 16035

# %%
# ==========================================================
# Load Model
# ==========================================================
model_name = "rikidharmawan/finetuning-sentiment-model-indobertweet-v2"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name)

print("\nLabel Model:")
print(model.config.id2label)

pipe = pipeline(
    "sentiment-analysis",
    model=model,
    tokenizer=tokenizer,
    device=device
)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/911 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.29k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/235k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/738k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/695 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B /  442MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# Label Model:
# {0: 'Negative', 1: 'Neutral', 2: 'Positive'}

# %%
def predict_sentiment(text):

    if pd.isna(text) or str(text).strip() == "":
        return pd.Series(["neutral", 0.0])

    try:
        result = pipe(
            str(text),
            truncation=True,
            max_length=512
        )[0]

        return pd.Series([
            result["label"].lower(),
            float(result["score"])
        ])

    except Exception as e:
        print(e)
        return pd.Series(["error", 0.0])

# %%
# ==========================================================
# Prediksi Sentimen
# ==========================================================
df[["label_sentimen","confidence_score"]] = df["tt_clean"].apply(
    predict_sentiment
)
# Out:
# [transformers] You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset

# %%
# ==========================================================
# Hasil Awal
# ==========================================================
print(df.head())
# Out:
#                                         tt_clean label_sentimen  \
# 0              woilah temen gw berenang disitu😹😹        neutral
# 1                                uya kuya kapan🗿        neutral
# 2                         "woy ini mahal anj" 😭😭       negative
# 3  jangan lupa eko patrio, uya kuya, nafa ubach,        neutral
# 4    reaksi syahroni pulang kaget jadi gelandang        neutral
#
#    confidence_score
# 0          0.467675
# 1          0.910259
# 2          0.993690
# 3          0.993353
# 4          0.991177

# %%
# ==========================================================
# Statistik Sentimen
# ==========================================================
print("\n==============================")
print("Jumlah Tiap Sentimen")
print("==============================")

print(df["label_sentimen"].value_counts())

print("\nPersentase Sentimen (%)")

print(
    round(
        df["label_sentimen"].value_counts(normalize=True)*100,
        2
    )
)
# Out:
# ==============================
# Jumlah Tiap Sentimen
# ==============================
# label_sentimen
# negative    8909
# neutral     3943
# positive    3183
# Name: count, dtype: int64
#
# Persentase Sentimen (%)
# label_sentimen
# negative    55.56
# neutral     24.59
# positive    19.85
# Name: proportion, dtype: float64

# %%
# ==========================================================
# Confidence > 0.80
# ==========================================================
high_conf = df[df["confidence_score"] > 0.80]

print("\n==============================")
print("Confidence Score > 0.80")
print("==============================")

print(f"Jumlah : {len(high_conf)}")
print(f"Persentase : {len(high_conf)/len(df)*100:.2f}%")

print("\nPer Sentimen")

print(high_conf["label_sentimen"].value_counts())
# Out:
# ==============================
# Confidence Score > 0.80
# ==============================
# Jumlah : 12879
# Persentase : 80.32%
#
# Per Sentimen
# label_sentimen
# negative    7794
# positive    2574
# neutral     2511
# Name: count, dtype: int64

# %%
# ==========================================================
# Statistik Confidence
# ==========================================================
print("\n==============================")
print("Statistik Confidence Score")
print("==============================")

print(df["confidence_score"].describe())
# Out:
# ==============================
# Statistik Confidence Score
# ==============================
# count    16035.000000
# mean         0.902509
# std          0.142903
# min          0.000000
# 25%          0.863375
# 50%          0.979347
# 75%          0.995321
# max          0.999242
# Name: confidence_score, dtype: float64

# %%
# ==========================================================
# Histogram Confidence
# ==========================================================
plt.figure(figsize=(8,5))

plt.hist(df["confidence_score"], bins=30)

plt.xlabel("Confidence Score")
plt.ylabel("Jumlah Data")
plt.title("Distribusi Confidence Score")

plt.show()

# %%
# ==========================================================
# Simpan Hasil
# ==========================================================
output_file = "/content/drive/MyDrive/SKRIPSI MANTAP/data sosmed/Tiktok/tt_pseudo.csv"

df.to_csv(output_file, index=False)

print(f"\nHasil disimpan di : {output_file}")
# Out:
# Hasil disimpan di : /content/drive/MyDrive/SKRIPSI MANTAP/data sosmed/Tiktok/tt_pseudo.csv
