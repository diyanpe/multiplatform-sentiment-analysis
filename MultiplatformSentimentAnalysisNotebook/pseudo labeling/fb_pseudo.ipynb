# %%
# !pip install -q transformers torch accelerate sentencepiece

# %%
# Import Library
# ==========================================================
import pandas as pd
import torch
import matplotlib.pyplot as plt

from transformers import (
    AutoTokenizer,
    AutoModelForSequenceClassification,
    pipeline
)

# %%
# ==========================================================
# Cek GPU
# ==========================================================
device = 0 if torch.cuda.is_available() else -1

if device == 0:
    print("Menggunakan GPU")
else:
    print("Menggunakan CPU")
# Out:
# Menggunakan GPU

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# ==========================================================
# Load Dataset
# ==========================================================
df = pd.read_csv("/content/drive/MyDrive/SKRIPSI MANTAP/data sosmed/.Process/Clean data/fb_clean.csv")

print(df.head())
print(f"\nJumlah data : {len(df)}")
# Out:
#                                             fb_clean
# 0                     tuntutan dalam 7 hari kedepan:
# 1  kalau ada pejabat yg korupsi, jangan harap lgi...
# 2  para pejabat publik sering pamer harta benda, ...
# 3  drpada fasilitas umum dan pertokoan ya mending...
# 4             hahaha it's hilarious, rampok dirampok
#
# Jumlah data : 12805

# %%
# ==========================================================
# Load Model
# ==========================================================
model_name = "rikidharmawan/finetuning-sentiment-model-indobertweet-v2"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name)

print("\nLabel Model:")
print(model.config.id2label)

pipe = pipeline(
    "sentiment-analysis",
    model=model,
    tokenizer=tokenizer,
    device=device
)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/911 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.29k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/235k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/738k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/695 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B /  442MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# Label Model:
# {0: 'Negative', 1: 'Neutral', 2: 'Positive'}

# %%
def predict_sentiment(text):

    if pd.isna(text) or str(text).strip() == "":
        return pd.Series(["neutral", 0.0])

    try:
        result = pipe(
            str(text),
            truncation=True,
            max_length=512
        )[0]

        return pd.Series([
            result["label"].lower(),
            float(result["score"])
        ])

    except Exception as e:
        print(e)
        return pd.Series(["error", 0.0])

# %%
# ==========================================================
# Prediksi Sentimen
# ==========================================================
df[["label_sentimen","confidence_score"]] = df["fb_clean"].apply(
    predict_sentiment
)
# Out:
# [transformers] You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset

# %%
# ==========================================================
# Hasil Awal
# ==========================================================
print(df.head())
# Out:
#                                             fb_clean label_sentimen  \
# 0                     tuntutan dalam 7 hari kedepan:        neutral
# 1  kalau ada pejabat yg korupsi, jangan harap lgi...       negative
# 2  para pejabat publik sering pamer harta benda, ...        neutral
# 3  drpada fasilitas umum dan pertokoan ya mending...       negative
# 4             hahaha it's hilarious, rampok dirampok       negative
#
#    confidence_score
# 0          0.969857
# 1          0.982749
# 2          0.472715
# 3          0.991846
# 4          0.993810

# %%
# ==========================================================
# Statistik Sentimen
# ==========================================================
print("\n==============================")
print("Jumlah Tiap Sentimen")
print("==============================")

print(df["label_sentimen"].value_counts())

print("\nPersentase Sentimen (%)")

print(
    round(
        df["label_sentimen"].value_counts(normalize=True)*100,
        2
    )
)
# Out:
# ==============================
# Jumlah Tiap Sentimen
# ==============================
# label_sentimen
# negative    9207
# neutral     1920
# positive    1678
# Name: count, dtype: int64
#
# Persentase Sentimen (%)
# label_sentimen
# negative    71.90
# neutral     14.99
# positive    13.10
# Name: proportion, dtype: float64

# %%
# ==========================================================
# Confidence > 0.80
# ==========================================================
high_conf = df[df["confidence_score"] > 0.80]

print("\n==============================")
print("Confidence Score > 0.80")
print("==============================")

print(f"Jumlah : {len(high_conf)}")
print(f"Persentase : {len(high_conf)/len(df)*100:.2f}%")

print("\nPer Sentimen")

print(high_conf["label_sentimen"].value_counts())
# Out:
# ==============================
# Confidence Score > 0.80
# ==============================
# Jumlah : 11001
# Persentase : 85.91%
#
# Per Sentimen
# label_sentimen
# negative    8418
# neutral     1327
# positive    1256
# Name: count, dtype: int64

# %%
# ==========================================================
# Statistik Confidence
# ==========================================================
print("\n==============================")
print("Statistik Confidence Score")
print("==============================")

print(df["confidence_score"].describe())
# Out:
# ==============================
# Statistik Confidence Score
# ==============================
# count    12805.000000
# mean         0.925000
# std          0.127735
# min          0.000000
# 25%          0.925907
# 50%          0.987797
# 75%          0.995632
# max          0.999170
# Name: confidence_score, dtype: float64

# %%
# ==========================================================
# Histogram Confidence
# ==========================================================
plt.figure(figsize=(8,5))

plt.hist(df["confidence_score"], bins=30)

plt.xlabel("Confidence Score")
plt.ylabel("Jumlah Data")
plt.title("Distribusi Confidence Score")

plt.show()

# %%
# ==========================================================
# Simpan Hasil
# ==========================================================
output_file = "/content/drive/MyDrive/SKRIPSI MANTAP/data sosmed/Facebook/fb_pseudo.csv"

df.to_csv(output_file, index=False)

print(f"\nHasil disimpan di : {output_file}")
# Out:
# Hasil disimpan di : /content/drive/MyDrive/SKRIPSI MANTAP/data sosmed/Facebook/fb_pseudo.csv
