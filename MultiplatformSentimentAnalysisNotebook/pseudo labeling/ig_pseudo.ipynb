# %%
# !pip install -q transformers torch accelerate sentencepiece

# %%
# Import Library
# ==========================================================
import pandas as pd
import torch
import matplotlib.pyplot as plt

from transformers import (
    AutoTokenizer,
    AutoModelForSequenceClassification,
    pipeline
)

# %%
# ==========================================================
# Cek GPU
# ==========================================================
device = 0 if torch.cuda.is_available() else -1

if device == 0:
    print("Menggunakan GPU")
else:
    print("Menggunakan CPU")
# Out:
# Menggunakan GPU

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# ==========================================================
# Load Dataset
# ==========================================================
df = pd.read_csv("/content/drive/MyDrive/SKRIPSI MANTAP/data sosmed/.Process/Clean data/ig_clean.csv")   # ganti sesuai nama file

print(df.head())
print(f"\nJumlah data : {len(df)}")
# Out:
#                                        ig_clean
# 0                               🔥 alhamdulillah
# 1                                      gaskan 🔥
# 2   nah ini baru mantap.,semangat rakyatku 🇮🇩💪🤲
# 3                            next deddy sitorus
# 4  serem yaa kalau masa sudah tak terkendali 😢,
#
# Jumlah data : 25094

# %%
# ==========================================================
# Load Model
# ==========================================================
model_name = "rikidharmawan/finetuning-sentiment-model-indobertweet-v2"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name)

print("\nLabel Model:")
print(model.config.id2label)

pipe = pipeline(
    "sentiment-analysis",
    model=model,
    tokenizer=tokenizer,
    device=device
)
# Out:
# config.json:   0%|          | 0.00/911 [00:00<?, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# tokenizer_config.json:   0%|          | 0.00/1.29k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/235k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/738k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/695 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B /  442MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# Label Model:
# {0: 'Negative', 1: 'Neutral', 2: 'Positive'}

# %%
def predict_sentiment(text):

    if pd.isna(text) or str(text).strip() == "":
        return pd.Series(["neutral", 0.0])

    try:
        result = pipe(
            str(text),
            truncation=True,
            max_length=512
        )[0]

        return pd.Series([
            result["label"].lower(),
            float(result["score"])
        ])

    except Exception as e:
        print(e)
        return pd.Series(["error", 0.0])

# %%
# ==========================================================
# Prediksi Sentimen
# ==========================================================
df[["label_sentimen","confidence_score"]] = df["ig_clean"].apply(
    predict_sentiment
)
# Out:
# [transformers] You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset

# %%
# ==========================================================
# Hasil Awal
# ==========================================================
print(df.head())
# Out:
#                                        ig_clean label_sentimen  \
# 0                               🔥 alhamdulillah       positive
# 1                                      gaskan 🔥       negative
# 2   nah ini baru mantap.,semangat rakyatku 🇮🇩💪🤲       positive
# 3                            next deddy sitorus        neutral
# 4  serem yaa kalau masa sudah tak terkendali 😢,       negative
#
#    confidence_score
# 0          0.996476
# 1          0.768281
# 2          0.995375
# 3          0.994973
# 4          0.996316

# %%
# ==========================================================
# Statistik Sentimen
# ==========================================================
print("\n==============================")
print("Jumlah Tiap Sentimen")
print("==============================")

print(df["label_sentimen"].value_counts())

print("\nPersentase Sentimen (%)")

print(
    round(
        df["label_sentimen"].value_counts(normalize=True)*100,
        2
    )
)
# Out:
# ==============================
# Jumlah Tiap Sentimen
# ==============================
# label_sentimen
# negative    14330
# neutral      6366
# positive     4398
# Name: count, dtype: int64
#
# Persentase Sentimen (%)
# label_sentimen
# negative    57.11
# neutral     25.37
# positive    17.53
# Name: proportion, dtype: float64

# %%
# ==========================================================
# Confidence > 0.80
# ==========================================================
high_conf = df[df["confidence_score"] > 0.80]

print("\n==============================")
print("Confidence Score > 0.80")
print("==============================")

print(f"Jumlah : {len(high_conf)}")
print(f"Persentase : {len(high_conf)/len(df)*100:.2f}%")

print("\nPer Sentimen")

print(high_conf["label_sentimen"].value_counts())
# Out:
# ==============================
# Confidence Score > 0.80
# ==============================
# Jumlah : 19966
# Persentase : 79.56%
#
# Per Sentimen
# label_sentimen
# negative    12456
# neutral      4129
# positive     3381
# Name: count, dtype: int64

# %%
# ==========================================================
# Statistik Confidence
# ==========================================================
print("\n==============================")
print("Statistik Confidence Score")
print("==============================")

print(df["confidence_score"].describe())
# Out:
# ==============================
# Statistik Confidence Score
# ==============================
# count    25094.000000
# mean         0.898637
# std          0.143848
# min          0.000000
# 25%          0.854604
# 50%          0.975659
# 75%          0.994643
# max          0.999224
# Name: confidence_score, dtype: float64

# %%
# ==========================================================
# Histogram Confidence
# ==========================================================
plt.figure(figsize=(8,5))

plt.hist(df["confidence_score"], bins=30)

plt.xlabel("Confidence Score")
plt.ylabel("Jumlah Data")
plt.title("Distribusi Confidence Score")

plt.show()

# %%
# ==========================================================
# Simpan Hasil
# ==========================================================
output_file = "/content/drive/MyDrive/SKRIPSI MANTAP/data sosmed/Instagram/ig_pseudo.csv"

df.to_csv(output_file, index=False)

print(f"\nHasil disimpan di : {output_file}")
# Out:
# Hasil disimpan di : /content/drive/MyDrive/SKRIPSI MANTAP/data sosmed/Instagram/ig_pseudo.csv
