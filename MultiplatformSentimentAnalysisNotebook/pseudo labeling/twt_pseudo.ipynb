# %%
# !pip install -q transformers torch accelerate sentencepiece

# %%
# Import Library
# ==========================================================
import pandas as pd
import torch
import matplotlib.pyplot as plt

from transformers import (
    AutoTokenizer,
    AutoModelForSequenceClassification,
    pipeline
)

# %%
# ==========================================================
# Cek GPU
# ==========================================================
device = 0 if torch.cuda.is_available() else -1

if device == 0:
    print("Menggunakan GPU")
else:
    print("Menggunakan CPU")
# Out:
# Menggunakan GPU

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# ==========================================================
# Load Dataset
# ==========================================================
df = pd.read_csv("/content/drive/MyDrive/SKRIPSI MANTAP/data sosmed/Clean data/twt_clean.csv")   # ganti sesuai nama file

print(df.head())
print(f"\nJumlah data : {len(df)}")
# Out:
#                                            twt_clean
# 0       warga bagi-bagi dollar dari brankas sahroni.
# 1                              terjemahkan postingan
# 2  man it was around 1.30ish and the satpam only ...
# 3  guys i also don’t know ada provokatornya atau ...
# 4  and i just wanted go home capek coy udah jam s...
#
# Jumlah data : 2128

# %%
# ==========================================================
# Load Model
# ==========================================================
model_name = "rikidharmawan/finetuning-sentiment-model-indobertweet-v2"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name)

print("\nLabel Model:")
print(model.config.id2label)

pipe = pipeline(
    "sentiment-analysis",
    model=model,
    tokenizer=tokenizer,
    device=device
)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/911 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.29k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/235k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/738k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/695 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/442M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# Label Model:
# {0: 'Negative', 1: 'Neutral', 2: 'Positive'}

# %%
def predict_sentiment(text):

    if pd.isna(text) or str(text).strip() == "":
        return pd.Series(["neutral", 0.0])

    try:
        result = pipe(
            str(text),
            truncation=True,
            max_length=512
        )[0]

        return pd.Series([
            result["label"].lower(),
            float(result["score"])
        ])

    except Exception as e:
        print(e)
        return pd.Series(["error", 0.0])

# %%
# ==========================================================
# Prediksi Sentimen
# ==========================================================
df[["label_sentimen","confidence_score"]] = df["twt_clean"].apply(
    predict_sentiment
)
# Out:
# [transformers] You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset

# %%
# ==========================================================
# Hasil Awal
# ==========================================================
print(df.head())
# Out:
#                                            twt_clean label_sentimen  \
# 0       warga bagi-bagi dollar dari brankas sahroni.        neutral
# 1                              terjemahkan postingan        neutral
# 2  man it was around 1.30ish and the satpam only ...       negative
# 3  guys i also don’t know ada provokatornya atau ...       negative
# 4  and i just wanted go home capek coy udah jam s...       negative
#
#    confidence_score
# 0          0.992309
# 1          0.997442
# 2          0.588271
# 3          0.843318
# 4          0.989855

# %%
# ==========================================================
# Statistik Sentimen
# ==========================================================
print("\n==============================")
print("Jumlah Tiap Sentimen")
print("==============================")

print(df["label_sentimen"].value_counts())

print("\nPersentase Sentimen (%)")

print(
    round(
        df["label_sentimen"].value_counts(normalize=True)*100,
        2
    )
)
# Out:
# ==============================
# Jumlah Tiap Sentimen
# ==============================
# label_sentimen
# negative    1336
# neutral      494
# positive     298
# Name: count, dtype: int64
#
# Persentase Sentimen (%)
# label_sentimen
# negative    62.78
# neutral     23.21
# positive    14.00
# Name: proportion, dtype: float64

# %%
# ==========================================================
# Confidence > 0.80
# ==========================================================
high_conf = df[df["confidence_score"] > 0.80]

print("\n==============================")
print("Confidence Score > 0.80")
print("==============================")

print(f"Jumlah : {len(high_conf)}")
print(f"Persentase : {len(high_conf)/len(df)*100:.2f}%")

print("\nPer Sentimen")

print(high_conf["label_sentimen"].value_counts())
# Out:
# ==============================
# Confidence Score > 0.80
# ==============================
# Jumlah : 1794
# Persentase : 84.30%
#
# Per Sentimen
# label_sentimen
# negative    1204
# neutral      352
# positive     238
# Name: count, dtype: int64

# %%
# ==========================================================
# Statistik Confidence
# ==========================================================
print("\n==============================")
print("Statistik Confidence Score")
print("==============================")

print(df["confidence_score"].describe())
# Out:
# ==============================
# Statistik Confidence Score
# ==============================
# count    2128.000000
# mean        0.918523
# std         0.133950
# min         0.381659
# 25%         0.903704
# 50%         0.987231
# 75%         0.996420
# max         0.999123
# Name: confidence_score, dtype: float64

# %%
# ==========================================================
# Histogram Confidence
# ==========================================================
plt.figure(figsize=(8,5))

plt.hist(df["confidence_score"], bins=30)

plt.xlabel("Confidence Score")
plt.ylabel("Jumlah Data")
plt.title("Distribusi Confidence Score")

plt.show()

# %%
# ==========================================================
# Simpan Hasil
# ==========================================================
output_file = "/content/drive/MyDrive/SKRIPSI MANTAP/data sosmed/Pseudo labeling data/twt_pseudo.csv"

df.to_csv(output_file, index=False)

print(f"\nHasil disimpan di : {output_file}")
# Out:
# Hasil disimpan di : /content/drive/MyDrive/SKRIPSI MANTAP/data sosmed/Pseudo labeling data/twt_pseudo.csv
