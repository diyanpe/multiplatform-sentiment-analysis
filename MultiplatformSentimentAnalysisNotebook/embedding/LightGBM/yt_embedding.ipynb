# %%
# !pip install transformers torch pandas tqdm

# %%
import pandas as pd
import torch
from transformers import AutoTokenizer, AutoModel
from tqdm import tqdm

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Path folder di Google Drive
folder_path = '/content/drive/MyDrive/SKRIPSI MANTAP/data sosmed/.Process/Clean data'

# Path file
file_path = f'{folder_path}/yt_clean.csv'

# Membaca CSV
df = pd.read_csv(
    file_path,
    sep=',',  # gunakan ',' jika disimpan dengan to_csv() default
    engine='python'
)

# Cek nama kolom
print(df.columns)

# Ambil kolom comment
texts = df["yt_clean"].astype(str).tolist()

print("Jumlah komentar:", len(texts))
# Out:
# Index(['yt_clean'], dtype='object')
# Jumlah komentar: 93878

# %%
model_name = "indolem/indobertweet-base-uncased"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModel.from_pretrained(model_name)

# Gunakan GPU jika tersedia
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
model.eval()
# Out:
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/1.10k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/235k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# pytorch_model.bin: reconstructing file:   0%|          |  0.00B /  445MB
# pytorch_model.bin: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# [transformers] BertModel LOAD REPORT from: indolem/indobertweet-base-uncased
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# cls.predictions.transform.dense.bias       | UNEXPECTED |  |
# cls.predictions.bias                       | UNEXPECTED |  |
# ...

# %%
def indobertweet_embedding(text_list, max_length=50):
    embeddings = []

    for text in tqdm(text_list):
        encoded = tokenizer(
            text,
            padding="max_length",
            truncation=True,
            max_length=max_length,
            return_tensors="pt"
        )

        encoded = {k: v.to(device) for k, v in encoded.items()}

        with torch.no_grad():
            output = model(**encoded)

        # Mean Pooling
        token_embeddings = output.last_hidden_state
        attention_mask = encoded["attention_mask"]

        mask = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
        masked_embeddings = token_embeddings * mask

        summed = torch.sum(masked_embeddings, dim=1)
        counts = torch.clamp(mask.sum(dim=1), min=1e-9)

        mean_pooled = summed / counts
        embeddings.append(mean_pooled.squeeze().cpu().numpy())

    return embeddings

# %%
embeddings = indobertweet_embedding(texts)

print("Jumlah embedding:", len(embeddings))
print("Dimensi embedding:", embeddings[0].shape)
# Out:
# Streaming output truncated to the last 5000 lines.
#  80%|███████▉  | 74910/93878 [18:38<04:25, 71.53it/s]
#
#  80%|███████▉  | 74918/93878 [18:38<04:25, 71.42it/s]
#
#  80%|███████▉  | 74926/93878 [18:38<04:28, 70.50it/s]
#
#  80%|███████▉  | 74934/93878 [18:38<04:27, 70.95it/s]
#
#  80%|███████▉  | 74942/93878 [18:38<04:24, 71.64it/s]
#
#  80%|███████▉  | 74950/93878 [18:39<04:22, 72.17it/s]
#
#  80%|███████▉  | 74958/93878 [18:39<04:19, 72.97it/s]
#
#  80%|███████▉  | 74966/93878 [18:39<04:23, 71.87it/s]
#
#  80%|███████▉  | 74974/93878 [18:39<04:17, 73.45it/s]
#
#  80%|███████▉  | 74982/93878 [18:39<04:26, 70.86it/s]
#
#  80%|███████▉  | 74990/93878 [18:39<04:23, 71.67it/s]
#
#  80%|███████▉  | 74998/93878 [18:39<04:20, 72.57it/s]
#
#  80%|███████▉  | 75006/93878 [18:39<04:14, 74.18it/s]
#
#  80%|███████▉  | 75014/93878 [18:39<04:12, 74.75it/s]
#
#  80%|███████▉  | 75022/93878 [18:39<04:08, 75.75it/s]
#
#  80%|███████▉  | 75030/93878 [18:40<04:06, 76.57it/s]
#
# ...

# %%
embedding_df = pd.DataFrame(embeddings)
embedding_df.columns = [f"emb_{i}" for i in range(embedding_df.shape[1])]

# Gabungkan dengan data asli
final_df = pd.concat([df.reset_index(drop=True), embedding_df], axis=1)

# Simpan hasil embedding
final_df.to_csv("yt_embed_lightgbm.csv", index=False)

print("Embedding berhasil disimpan!")
# Out:
# Embedding berhasil disimpan!

# %%
# !zip yt_embed_lightgbm.zip yt_embed_lightgbm.csv
# Out:
#   adding: yt_embed_lightgbm.csv (deflated 57%)

# %%
from google.colab import files

files.download("yt_embed_lightgbm.csv")

# %%
import numpy as np

np.save("yt_embed_lightgbm.npy", embeddings)
from google.colab import files

files.download("yt_embed_lightgbm.npy")

# %%
# !zip yt_embed_lightgbm.zip yt_embed_lightgbm.npy
# Out:
#   adding: yt_embed_lightgbm.npy (deflated 7%)

# %%
import os

folder_path = '/content/drive/MyDrive/SKRIPSI MANTAP/data sosmed/Youtube'

os.makedirs(folder_path, exist_ok=True)

# %% [markdown]
# Simpan ke gdrive

# %%
output_path = f'{folder_path}/yt_embed_lightgbm.csv'

final_df.to_csv(output_path, index=False)

print("File berhasil disimpan di:")
print(output_path)
# Out:
# File berhasil disimpan di:
# /content/drive/MyDrive/SKRIPSI MANTAP/data sosmed/Youtube/yt_embed_lightgbm.csv
